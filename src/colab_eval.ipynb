#   inflating: CamVid/test_labels/Seq05VD_f00480_L.png
#   inflating: CamVid/test_labels/Seq05VD_f00510_L.png
#   inflating: CamVid/test_labels/Seq05VD_f00540_L.png
#   inflating: CamVid/test_labels/Seq05VD_f00570_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01080_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01110_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01140_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01170_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01380_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01410_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01740_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01770_L.png
#   inflating: CamVid/test_labels/Seq05VD_f01980_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02010_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02040_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02070_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02580_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02610_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02640_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02670_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02880_L.png
#   inflating: CamVid/test_labels/Seq05VD_f02910_L.png
#   inflating: CamVid/test_labels/Seq05VD_f03240_L.png
#   inflating: CamVid/test_labels/Seq05VD_f03270_L.png
#   inflating: CamVid/test_labels/Seq05VD_f03480_L.png
#   inflating: CamVid/test_labels/Seq05VD_f03510_L.png
#   inflating: CamVid/test_labels/Seq05VD_f03540_L.png
#   inflating: CamVid/test_labels/Seq05VD_f03570_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04080_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04110_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04140_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04170_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04380_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04410_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04740_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04770_L.png
#   inflating: CamVid/test_labels/Seq05VD_f04980_L.png
#   inflating: CamVid/test_labels/Seq05VD_f05010_L.png
#   inflating: CamVid/test_labels/Seq05VD_f05040_L.png
#   inflating: CamVid/test_labels/Seq05VD_f05070_L.png
#   inflating: CamVid/train/0001TP_009210.png
#   inflating: CamVid/train/0001TP_009240.png
#   inflating: CamVid/train/0001TP_009390.png
#   inflating: CamVid/train/0001TP_009420.png
#   inflating: CamVid/train/0001TP_009450.png
#   inflating: CamVid/train/0001TP_009480.png
#   inflating: CamVid/train/0001TP_009510.png
#   inflating: CamVid/train/0001TP_009540.png
#   inflating: CamVid/train/0001TP_009690.png
#   inflating: CamVid/train/0001TP_009720.png
#   inflating: CamVid/train/0001TP_009750.png
#   inflating: CamVid/train/0001TP_009780.png
#   inflating: CamVid/train/0001TP_009810.png
#   inflating: CamVid/train/0001TP_009840.png
#   inflating: CamVid/train/Seq05VD_f00720.png
#   inflating: CamVid/train/Seq05VD_f00750.png
#   inflating: CamVid/train/Seq05VD_f00900.png
#   inflating: CamVid/train/Seq05VD_f00930.png
#   inflating: CamVid/train/Seq05VD_f00960.png
#   inflating: CamVid/train/Seq05VD_f00990.png
#   inflating: CamVid/train/Seq05VD_f01020.png
#   inflating: CamVid/train/Seq05VD_f01050.png
#   inflating: CamVid/train/Seq05VD_f01200.png
#   inflating: CamVid/train/Seq05VD_f01230.png
#   inflating: CamVid/train/Seq05VD_f01260.png
#   inflating: CamVid/train/Seq05VD_f01290.png
#   inflating: CamVid/train/Seq05VD_f01320.png
#   inflating: CamVid/train/Seq05VD_f01350.png
#   inflating: CamVid/train/Seq05VD_f01500.png
#   inflating: CamVid/train/Seq05VD_f01530.png
#   inflating: CamVid/train/Seq05VD_f01560.png
#   inflating: CamVid/train/Seq05VD_f01590.png
#   inflating: CamVid/train/Seq05VD_f01620.png
#   inflating: CamVid/train/Seq05VD_f01650.png
#   inflating: CamVid/train/Seq05VD_f01800.png
#   inflating: CamVid/train/Seq05VD_f01830.png
#   inflating: CamVid/train/Seq05VD_f01860.png
#   inflating: CamVid/train/Seq05VD_f01890.png
#   inflating: CamVid/train/Seq05VD_f01920.png
#   inflating: CamVid/train/Seq05VD_f01950.png
#   inflating: CamVid/train/Seq05VD_f02100.png
#   inflating: CamVid/train/Seq05VD_f02130.png
#   inflating: CamVid/train/Seq05VD_f02160.png
#   inflating: CamVid/train/Seq05VD_f02190.png
#   inflating: CamVid/train/Seq05VD_f02220.png
#   inflating: CamVid/train/Seq05VD_f02250.png
#   inflating: CamVid/train/Seq05VD_f02400.png
#   inflating: CamVid/train/Seq05VD_f02430.png
#   inflating: CamVid/train/Seq05VD_f02460.png
#   inflating: CamVid/train/Seq05VD_f02490.png
#   inflating: CamVid/train/Seq05VD_f02520.png
#   inflating: CamVid/train/Seq05VD_f02550.png
#   inflating: CamVid/train/Seq05VD_f02700.png
#   inflating: CamVid/train/Seq05VD_f02730.png
#   inflating: CamVid/train/Seq05VD_f02760.png
#   inflating: CamVid/train/Seq05VD_f02790.png
#   inflating: CamVid/train/Seq05VD_f02820.png
#   inflating: CamVid/train/Seq05VD_f02850.png
#   inflating: CamVid/train/Seq05VD_f03000.png
#   inflating: CamVid/train/Seq05VD_f03030.png
#   inflating: CamVid/train/Seq05VD_f03060.png
#   inflating: CamVid/train/Seq05VD_f03090.png
#   inflating: CamVid/train/Seq05VD_f03120.png
#   inflating: CamVid/train/Seq05VD_f03150.png
#   inflating: CamVid/train/Seq05VD_f03300.png
#   inflating: CamVid/train/Seq05VD_f03330.png
#   inflating: CamVid/train/Seq05VD_f03360.png
#   inflating: CamVid/train/Seq05VD_f03390.png
#   inflating: CamVid/train/Seq05VD_f03420.png
#   inflating: CamVid/train/Seq05VD_f03450.png
#   inflating: CamVid/train/Seq05VD_f03600.png
#   inflating: CamVid/train/Seq05VD_f03630.png
#   inflating: CamVid/train/Seq05VD_f03660.png
#   inflating: CamVid/train/Seq05VD_f03690.png
#   inflating: CamVid/train/Seq05VD_f03720.png
#   inflating: CamVid/train/Seq05VD_f03750.png
#   inflating: CamVid/train/Seq05VD_f03900.png
#   inflating: CamVid/train/Seq05VD_f03930.png
#   inflating: CamVid/train/Seq05VD_f03960.png
#   inflating: CamVid/train/Seq05VD_f03990.png
#   inflating: CamVid/train/Seq05VD_f04020.png
#   inflating: CamVid/train/Seq05VD_f04050.png
#   inflating: CamVid/train/Seq05VD_f04200.png
#   inflating: CamVid/train/Seq05VD_f04230.png
#   inflating: CamVid/train/Seq05VD_f04260.png
#   inflating: CamVid/train/Seq05VD_f04290.png
#   inflating: CamVid/train/Seq05VD_f04320.png
#   inflating: CamVid/train/Seq05VD_f04350.png
#   inflating: CamVid/train/Seq05VD_f04500.png
#   inflating: CamVid/train/Seq05VD_f04530.png
#   inflating: CamVid/train/Seq05VD_f04560.png
#   inflating: CamVid/train/Seq05VD_f04590.png
#   inflating: CamVid/train/Seq05VD_f04620.png
#   inflating: CamVid/train/Seq05VD_f04650.png
#   inflating: CamVid/train/Seq05VD_f04800.png
#   inflating: CamVid/train/Seq05VD_f04830.png
#   inflating: CamVid/train/Seq05VD_f04860.png
#   inflating: CamVid/train/Seq05VD_f04890.png
#   inflating: CamVid/train/Seq05VD_f04920.png
#   inflating: CamVid/train/Seq05VD_f04950.png
#   inflating: CamVid/train/Seq05VD_f05100.png
#   inflating: CamVid/train_labels/0001TP_009210_L.png
#   inflating: CamVid/train_labels/0001TP_009240_L.png
#   inflating: CamVid/train_labels/0001TP_009390_L.png
#   inflating: CamVid/train_labels/0001TP_009420_L.png
#   inflating: CamVid/train_labels/0001TP_009450_L.png
#   inflating: CamVid/train_labels/0001TP_009480_L.png
#   inflating: CamVid/train_labels/0001TP_009510_L.png
#   inflating: CamVid/train_labels/0001TP_009540_L.png
#   inflating: CamVid/train_labels/0001TP_009690_L.png
#   inflating: CamVid/train_labels/0001TP_009720_L.png
#   inflating: CamVid/train_labels/0001TP_009750_L.png
#   inflating: CamVid/train_labels/0001TP_009780_L.png
#   inflating: CamVid/train_labels/0001TP_009810_L.png
#   inflating: CamVid/train_labels/0001TP_009840_L.png
#   inflating: CamVid/train_labels/0001TP_009990_L.png
#   inflating: CamVid/train_labels/0001TP_010020_L.png
#   inflating: CamVid/train_labels/0001TP_010050_L.png
#   inflating: CamVid/train_labels/0001TP_010080_L.png
#   inflating: CamVid/train_labels/0001TP_010110_L.png
#   inflating: CamVid/train_labels/0001TP_010140_L.png
#   inflating: CamVid/train_labels/0001TP_010290_L.png
#   inflating: CamVid/train_labels/0001TP_010320_L.png
#   inflating: CamVid/train_labels/0001TP_010350_L.png
#   inflating: CamVid/train_labels/0001TP_010380_L.png
#   inflating: CamVid/train_labels/0006R0_f00930_L.png
#   inflating: CamVid/train_labels/0006R0_f00960_L.png
#   inflating: CamVid/train_labels/0006R0_f01110_L.png
#   inflating: CamVid/train_labels/0006R0_f01140_L.png
#   inflating: CamVid/train_labels/0006R0_f01170_L.png
#   inflating: CamVid/train_labels/0006R0_f01200_L.png
#   inflating: CamVid/train_labels/0006R0_f01230_L.png
#   inflating: CamVid/train_labels/0006R0_f01260_L.png
#   inflating: CamVid/train_labels/0006R0_f01410_L.png
#   inflating: CamVid/train_labels/0006R0_f01440_L.png
#   inflating: CamVid/train_labels/0006R0_f01470_L.png
#   inflating: CamVid/train_labels/0006R0_f01500_L.png
#   inflating: CamVid/train_labels/0006R0_f01530_L.png
#   inflating: CamVid/train_labels/0006R0_f01560_L.png
#   inflating: CamVid/train_labels/0006R0_f01710_L.png
#   inflating: CamVid/train_labels/0006R0_f01740_L.png
#   inflating: CamVid/train_labels/0006R0_f01770_L.png
#   inflating: CamVid/train_labels/0006R0_f01800_L.png
#   inflating: CamVid/train_labels/0006R0_f01830_L.png
#   inflating: CamVid/train_labels/0006R0_f01860_L.png
#   inflating: CamVid/train_labels/0006R0_f02010_L.png
#   inflating: CamVid/train_labels/0006R0_f02040_L.png
#   inflating: CamVid/train_labels/0006R0_f02070_L.png
#   inflating: CamVid/train_labels/0006R0_f02100_L.png
#   inflating: CamVid/train_labels/0006R0_f02130_L.png
#   inflating: CamVid/train_labels/0006R0_f02160_L.png
#   inflating: CamVid/train_labels/0006R0_f02310_L.png
#   inflating: CamVid/train_labels/0006R0_f02340_L.png
#   inflating: CamVid/train_labels/0006R0_f02370_L.png
#   inflating: CamVid/train_labels/0006R0_f02400_L.png
#   inflating: CamVid/train_labels/0006R0_f02430_L.png
#   inflating: CamVid/train_labels/0006R0_f02460_L.png
#   inflating: CamVid/train_labels/0006R0_f02610_L.png
#   inflating: CamVid/train_labels/0006R0_f02640_L.png
#   inflating: CamVid/train_labels/0006R0_f02670_L.png
#   inflating: CamVid/train_labels/0006R0_f02700_L.png
#   inflating: CamVid/train_labels/0006R0_f02730_L.png
#   inflating: CamVid/train_labels/0006R0_f02760_L.png
#   inflating: CamVid/train_labels/0006R0_f02910_L.png
#   inflating: CamVid/train_labels/0006R0_f02940_L.png
#   inflating: CamVid/train_labels/0006R0_f02970_L.png
#   inflating: CamVid/train_labels/0006R0_f03000_L.png
#   inflating: CamVid/train_labels/0006R0_f03030_L.png
#   inflating: CamVid/train_labels/0006R0_f03060_L.png
#   inflating: CamVid/train_labels/0006R0_f03210_L.png
#   inflating: CamVid/train_labels/0006R0_f03240_L.png
#   inflating: CamVid/train_labels/0006R0_f03270_L.png
#   inflating: CamVid/train_labels/0006R0_f03300_L.png
#   inflating: CamVid/train_labels/0006R0_f03330_L.png
#   inflating: CamVid/train_labels/0006R0_f03360_L.png
#   inflating: CamVid/train_labels/0006R0_f03510_L.png
#   inflating: CamVid/train_labels/0006R0_f03540_L.png
#   inflating: CamVid/train_labels/0006R0_f03570_L.png
#   inflating: CamVid/train_labels/0006R0_f03600_L.png
#   inflating: CamVid/train_labels/0006R0_f03630_L.png
#   inflating: CamVid/train_labels/0006R0_f03660_L.png
#   inflating: CamVid/train_labels/0006R0_f03810_L.png
#   inflating: CamVid/train_labels/0006R0_f03840_L.png
#   inflating: CamVid/train_labels/0006R0_f03870_L.png
#   inflating: CamVid/train_labels/0006R0_f03900_L.png
#   inflating: CamVid/train_labels/0006R0_f03930_L.png
os
import torch
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from tqdm import tqdm
import argparse

from fcn_with_skips import UNet
from dataset import SegmentationDataset, get_val_transform, CAMVID_CLASSES, CAMVID_COLORS

def evaluate_model(model, test_loader, device, save_dir):
    """Evaluate model on test set and save visualizations"""
    model.eval()
    class_dice_scores = {cls: [] for cls in CAMVID_CLASSES}

    os.makedirs(os.path.join(save_dir, 'predictions'), exist_ok=True)

    with torch.no_grad():
        for i, (images, masks) in enumerate(tqdm(test_loader, desc='Evaluating')):
            images = images.to(device)
            masks = masks.to(device)

            # Forward pass
            outputs = model(images)
            predictions = torch.softmax(outputs, dim=1)
            predictions = torch.argmax(predictions, dim=1)

            # Calculate per-class Dice scores
            for class_idx, class_name in enumerate(CAMVID_CLASSES):
                pred_mask = (predictions == class_idx)
                target_mask = (masks == class_idx)

                intersection = (pred_mask & target_mask).sum().float()
                union = pred_mask.sum() + target_mask.sum()

                if union > 0:
                    dice = (2. * intersection) / (union + 1e-8)
                    class_dice_scores[class_name].append(dice.item())

            # Save visualizations for first batch
            if i == 0:
                save_predictions(images, masks, predictions, save_dir)

    # Calculate and print average Dice score for each class
    print("\nPer-class Dice Scores:")
    total_dice = 0
    num_classes = 0
    for class_name, scores in class_dice_scores.items():
        if scores:  # Only consider classes that appeared in the test set
            avg_dice = np.mean(scores)
            print(f"{class_name}: {avg_dice:.4f}")
            total_dice += avg_dice
            num_classes += 1

    avg_dice = total_dice / num_classes if num_classes > 0 else 0
    print(f"\nOverall Average Dice Score: {avg_dice:.4f}")

    return avg_dice, class_dice_scores

def save_predictions(images, masks, predictions, save_dir, num_samples=5):
    """Save visualization of predictions"""
    images = images.cpu()
    masks = masks.cpu()
    predictions = predictions.cpu()

    # Denormalize images
    mean = torch.tensor([0.485, 0.456, 0.406]).view(1, 3, 1, 1)
    std = torch.tensor([0.229, 0.224, 0.225]).view(1, 3, 1, 1)
    images = images * std + mean

    def create_color_mask(indices):
        """Convert class indices to RGB mask"""
        color_mask = np.zeros((*indices.shape, 3), dtype=np.uint8)
        for class_idx, color in enumerate(CAMVID_COLORS):
            mask = (indices == class_idx)
            color_mask[mask] = color
        return color_mask

    for idx in range(min(num_samples, len(images))):
        fig, axes = plt.subplots(1, 3, figsize=(15, 5))

        # Plot original image
        # Changed to select random images, so they're not all the same like they are in order
        img = images[idx].permute(1, 2, 0).numpy()
        img = np.clip(img, 0, 1)
        axes[0].imshow(img)
        axes[0].set_title('Original Image')
        axes[0].axis('off')

        # Plot ground truth mask
        mask_rgb = create_color_mask(masks[idx].numpy())
        axes[1].imshow(mask_rgb)
        axes[1].set_title('Ground Truth')
        axes[1].axis('off')

        # Plot prediction
        pred_rgb = create_color_mask(predictions[idx].numpy())
        axes[2].imshow(pred_rgb)
        axes[2].set_title('Prediction')
        axes[2].axis('off')

        plt.tight_layout()
        plt.savefig(os.path.join(save_dir, 'predictions', f'sample_{idx}.png'))
        plt.close()

def main():
    # parser = argparse.ArgumentParser(description='Evaluate U-Net model')
    # parser.add_argument('--model_path', type=str, default="best_model.pth", help='Path to saved model')
    # parser.add_argument('--test_dir', type=str, default='data/test', help='Path to test data directory')
    # parser.add_argument('--batch_size', type=int, default=8, help='Batch size')
    # parser.add_argument('--image_size', type=int, default=256, help='Image size')
    # args = parser.parse_args()
    model_path = "/content/best_model.pth"
    test_dir = "/content/data/test"
    batch_size = 4
    image_size = 256

    # Set device - check for MPS (Apple Silicon GPU) first, then CUDA, then fall back to CPU
    if torch.backends.mps.is_available():
        device = torch.device("mps")
        print("Using MPS (Apple Silicon GPU)")
    elif torch.cuda.is_available():
        device = torch.device("cuda")
        print("Using CUDA GPU")
    else:
        device = torch.device("cpu")
        print("Using CPU")

    # Load model
    model = UNet(in_channels=3, out_channels=len(CAMVID_CLASSES)).to(device)
    checkpoint = torch.load(model_path, map_location=device)
    model.load_state_dict(checkpoint['model_state_dict'])
    print(f'Loaded model from epoch {checkpoint["epoch"]} with validation loss {checkpoint["val_loss"]:.4f}')

    # Create test dataset and loader
    test_dataset = SegmentationDataset(
        transform=get_val_transform(image_size)
    )

    test_loader = DataLoader(
        test_dataset,
        batch_size=batch_size,
        shuffle=False,
        num_workers=4
    )

    # Create save directory
    save_dir = os.path.dirname(model_path)

    # Evaluate model
    avg_dice, class_dice_scores = evaluate_model(model, test_loader, device, save_dir)

    # Save results
    results = {
        'avg_dice': avg_dice,
        'class_dice_scores': {k: np.mean(v) if v else 0 for k, v in class_dice_scores.items()},
        'model_path': model_path,
        'test_dir': test_dir,
        'image_size': image_size,
        'batch_size': batch_size
    }

    with open(os.path.join(save_dir, 'evaluation_results.txt'), 'w') as f:
        for key, value in results.items():
            if key == 'class_dice_scores':
                f.write(f'{key}:\n')
                for class_name, score in value.items():
                    f.write(f'  {class_name}: {score:.4f}\n')
            else:
                f.write(f'{key}: {value}\n')

if __name__ == '__main__':
    main()
# Out:
# Using CPU
# Initial vals
# 3
# 32
# FTRS
# 512
# <ipython-input-4-41cfebb01e17>:135: FutureWarning: You are using `torch.load` with `weights_only=False` (the current default value), which uses the default pickle module implicitly. It is possible to construct malicious pickle data which will execute arbitrary code during unpickling (See https://github.com/pytorch/pytorch/blob/main/SECURITY.md#untrusted-models for more details). In a future release, the default value for `weights_only` will be flipped to `True`. This limits the functions that could be executed during unpickling. Arbitrary objects will no longer be allowed to be loaded via this mode unless they are explicitly allowlisted by the user via `torch.serialization.add_safe_globals`. We recommend you start setting `weights_only=True` for any use case where you don't have full control of the loaded file. Please open an issue on GitHub for any issues related to this experimental feature.
#   checkpoint = torch.load(model_path, map_location=device)
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:617: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(
# Loaded model from epoch 28 with validation loss 0.8192
# Evaluating: 100%|██████████| 93/93 [1:02:46<00:00, 40.50s/it]
# Per-class Dice Scores:
# Animal: 0.0000
# Archway: 0.0000
# Bicyclist: 0.0000
# Bridge: 0.0000
# Building: 0.7226
# Car: 0.4483
# CartLuggagePram: 0.0000
# Child: 0.0000
# Column_Pole: 0.0000
# Fence: 0.1426
# LaneMkgsDriv: 0.3073
# LaneMkgsNonDriv: 0.0000
# Misc_Text: 0.0000
# MotorcycleScooter: 0.0000
# OtherMoving: 0.0000
# ParkingBlock: 0.0000
# Pedestrian: 0.0000
# Road: 0.9110
# RoadShoulder: 0.0000
# Sidewalk: 0.6186
# SignSymbol: 0.0000
# Sky: 0.9274
# SUVPickupTruck: 0.0000
# TrafficCone: 0.0000
# TrafficLight: 0.0000
# Tree: 0.6143
# Truck_Bus: 0.0000
# Tunnel: 0.0000
# VegetationMisc: 0.1589
# Void: 0.0009
# Wall: 0.0730
#
# Overall Average Dice Score: 0.1589
